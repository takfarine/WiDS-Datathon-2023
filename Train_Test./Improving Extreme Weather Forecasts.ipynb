# %% [markdown]
# ## Setup

# %%
import numpy as np 
import pandas as pd 
import os, gc
import lightgbm as lgb
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler,RobustScaler
import joblib
from sklearn.metrics import log_loss
from lightgbm import LGBMRegressor,log_evaluation
from sklearn.preprocessing import StandardScaler
import optuna
from sklearn.ensemble import BaggingRegressor
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from catboost import CatBoostRegressor

train_df = pd.read_csv('/kaggle/input/widsdatathon2023/train_data.csv')
test_df = pd.read_csv('/kaggle/input/widsdatathon2023/test_data.csv')
submission = pd.read_csv('/kaggle/input/widsdatathon2023/sample_solution.csv')

def startdate_info(train, test):
    train_df.dropna(inplace=True)
    train_df['startdate'] = pd.to_datetime(train_df["startdate"])
    train_df['year'] = train_df['startdate'].dt.year
    train_df['month'] =train_df['startdate'].dt.month
    train_df['day_of_year'] = train_df['startdate'].dt.dayofyear

    test_df['startdate'] = pd.to_datetime(test_df["startdate"])
    test_df['year'] = test_df['startdate'].dt.year
    test_df['month'] =test_df['startdate'].dt.month
    test_df['day_of_year'] = test_df['startdate'].dt.dayofyear
    return train, test

def categorical_encode(train, test):
    le = LabelEncoder()
    train['climateregions__climateregion'] = le.fit_transform(train['climateregions__climateregion'])
    test['climateregions__climateregion'] = le.transform(test['climateregions__climateregion'])
    return train, test

train_df,test_df= startdate_info(train_df,test_df)
train_df,test_df=categorical_encode(train_df,test_df)

ycol ='contest-tmp2m-14d__tmp2m'
features =list(filter(lambda x: x not in [ycol, 'index','startdate'], train_df.columns))
target=train_df['contest-tmp2m-14d__tmp2m']
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from skopt.space import Real, Integer, Categorical
from skopt import BayesSearchCV
def run_model(train_df, test_df):
    # Split the training set into two parts, for use in ensembling
    train_df1, train_df2 = train_test_split(train_df, test_size=0.5, random_state=42)
    T1=train_df1['contest-tmp2m-14d__tmp2m']
    T2=train_df2['contest-tmp2m-14d__tmp2m']
    
    scaler = StandardScaler()
    train_df1 = train_df1[features]
    train_df2 = train_df2[features]
    test_df = test_df[features]
    train_df1[features] = scaler.fit_transform(train_df1[features])
    train_df2[features] = scaler.transform(train_df2[features])
    test_df[features] = scaler.transform(test_df[features])
    
    # Define the search spaces for the different CatBoostRegressor models
    search_spaces = [    
        {        
            'learning_rate': Real(0.001, 0.1, 'log-uniform'),        
            'depth': Integer(3, 6),        
            'l2_leaf_reg': Real(1e-3, 1e-1, 'log-uniform'),        
            'random_strength': Real(10, 50, 'log-uniform'),        
            'grow_policy': Categorical(['Lossguide', 'Depthwise']),
            'max_bin': Integer(100, 300),
            'min_data_in_leaf': Integer(10, 50),
            'bootstrap_type': Categorical(['Bayesian']),
        },
        {
            'learning_rate': Real(0.01, 0.3, 'log-uniform'),
            'depth': Integer(6, 10),
            'l2_leaf_reg': Real(1e-5, 1e-3, 'log-uniform'),
            'random_strength': Real(5, 20, 'log-uniform'),
            'grow_policy': Categorical(['Lossguide']),
            'max_bin': Integer(200, 400),
            'min_data_in_leaf': Integer(5, 20),
            'bootstrap_type': Categorical(['Bayesian', 'Bernoulli']),
        },
        {
            'learning_rate': Real(0.01, 0.1, 'log-uniform'),
            'depth': Integer(3, 6),
            'l2_leaf_reg': Real(1e-3, 1e-1, 'log-uniform'),
            'random_strength': Real(10, 50, 'log-uniform'),
            'grow_policy': Categorical(['Lossguide', 'Depthwise']),
            'max_bin': Integer(100, 300),
            'min_data_in_leaf': Integer(10, 50),
            'bootstrap_type': Categorical(['Bayesian']),
        }
    ]

    # Train multiple CatBoostRegressor models with different hyperparameters
    models = []
    for i, search_space in enumerate(search_spaces):
        opt = BayesSearchCV(
            estimator=CatBoostRegressor(verbose=500,task_type="GPU", devices='0:1'),
            search_spaces=search_space,
            scoring='neg_mean_squared_error',
            cv=KFold(n_splits=5, shuffle=True, random_state=2022),
            n_jobs=1,
            n_iter=20,
            verbose=1,
            random_state=42
        )
        opt.fit(train_df1, T1)
        best_params = opt.best_params_
        model = CatBoostRegressor(verbose=500, **best_params,task_type="GPU", devices='0:1')
        model.fit(train_df1[features], T1)
        models.append(model)
    
    # Combine the predictions from the individual models using a StackingRegressor
    stacker = StackingRegressor(
        estimators=[('model%d' % i, model) for i, model in enumerate(models)],
        final_estimator=CatBoostRegressor(verbose=500,task_type="GPU", devices='0:1'),
        cv=KFold(n_splits=5, shuffle=True, random_state=2022),
        passthrough=True
    )
    
    
    
    
    kf = KFold(n_splits=5, shuffle=True, random_state=0)
    oof = np.zeros(len(train_df))
    predictions = np.zeros(len(test_df))
    rmse = 0
    for fold, (train_index, val_index) in enumerate(kf.split(train_df2)):
        print("Fold {}".format(fold))
        X_train, X_val = train_df2.iloc[train_index], train_df2.iloc[val_index]
        y_train, y_val = T2.iloc[train_index], T2.iloc[val_index]
        stacker.fit(X_train, y_train)
        fold_predictions =stacker.predict(X_val)
        rmse += np.sqrt(mean_squared_error(y_val, fold_predictions)) / kf.n_splits
        print("CV RMSE:", rmse)
        oof[val_index] = fold_predictions
        predictions += stacker.predict(test_df) / kf.n_splits

    return predictions

# %%
pred= run_model(train_df, test_df)
submission[ycol] = pred
submission.to_csv('submission.csv', index = False)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.7311944	total: 123ms	remaining: 2m 2s
# 500:	learn: 0.9471450	total: 50.9s	remaining: 50.7s
# 999:	learn: 0.7496999	total: 1m 39s	remaining: 0us
# 0:	learn: 9.7487273	total: 85.7ms	remaining: 1m 25s
# 500:	learn: 0.9476800	total: 49.7s	remaining: 49.5s
# 999:	learn: 0.7497913	total: 1m 36s	remaining: 0us
# 0:	learn: 9.7249062	total: 143ms	remaining: 2m 22s
# 500:	learn: 0.9469696	total: 49.3s	remaining: 49.1s
# 999:	learn: 0.7483871	total: 1m 37s	remaining: 0us
# 0:	learn: 9.7356132	total: 101ms	remaining: 1m 40s
# 500:	learn: 0.9485159	total: 50.2s	remaining: 50s
# 999:	learn: 0.7487685	total: 1m 38s	remaining: 0us
# 0:	learn: 9.7428429	total: 79ms	remaining: 1m 18s
# 500:	learn: 0.9404855	total: 50.6s	remaining: 50.4s
# 999:	learn: 0.7461619	total: 1m 38s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.4319333	total: 63.9ms	remaining: 1m 3s
# 500:	learn: 0.5627659	total: 28s	remaining: 27.9s
# 999:	learn: 0.4218393	total: 55.5s	remaining: 0us
# 0:	learn: 9.4490539	total: 54.5ms	remaining: 54.5s
# 500:	learn: 0.5597624	total: 27.6s	remaining: 27.5s
# 999:	learn: 0.4189754	total: 53.9s	remaining: 0us
# 0:	learn: 9.4262415	total: 58.8ms	remaining: 58.8s
# 500:	learn: 0.5590117	total: 27.3s	remaining: 27.2s
# 999:	learn: 0.4161837	total: 53.7s	remaining: 0us
# 0:	learn: 9.4368088	total: 59.9ms	remaining: 59.9s
# 500:	learn: 0.5624894	total: 26.8s	remaining: 26.7s
# 999:	learn: 0.4223836	total: 53.1s	remaining: 0us
# 0:	learn: 9.4433528	total: 61.9ms	remaining: 1m 1s
# 500:	learn: 0.5565949	total: 29.2s	remaining: 29.1s
# 999:	learn: 0.4188497	total: 58.5s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.9119034	total: 73.8ms	remaining: 1m 13s
# 500:	learn: 3.4799467	total: 32.9s	remaining: 32.7s
# 999:	learn: 1.6905446	total: 1m 6s	remaining: 0us
# 0:	learn: 9.9297184	total: 93ms	remaining: 1m 32s
# 500:	learn: 3.4839924	total: 34.6s	remaining: 34.5s
# 999:	learn: 1.6910872	total: 1m 7s	remaining: 0us
# 0:	learn: 9.9054090	total: 71.7ms	remaining: 1m 11s
# 500:	learn: 3.4805559	total: 33.5s	remaining: 33.4s
# 999:	learn: 1.6931542	total: 1m 6s	remaining: 0us
# 0:	learn: 9.9163759	total: 73.1ms	remaining: 1m 13s
# 500:	learn: 3.4812810	total: 33.7s	remaining: 33.5s
# 999:	learn: 1.6910266	total: 1m 5s	remaining: 0us
# 0:	learn: 9.9237311	total: 73.2ms	remaining: 1m 13s
# 500:	learn: 3.4827664	total: 34.3s	remaining: 34.1s
# 999:	learn: 1.6919755	total: 1m 6s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.8327034	total: 57.6ms	remaining: 57.5s
# 500:	learn: 1.3628795	total: 28.2s	remaining: 28.1s
# 999:	learn: 1.1245567	total: 54s	remaining: 0us
# 0:	learn: 9.8504008	total: 59.8ms	remaining: 59.8s
# 500:	learn: 1.3593798	total: 27.1s	remaining: 27s
# 999:	learn: 1.1226762	total: 53.8s	remaining: 0us
# 0:	learn: 9.8263535	total: 61.4ms	remaining: 1m 1s
# 500:	learn: 1.3668936	total: 27.5s	remaining: 27.4s
# 999:	learn: 1.1270893	total: 53.3s	remaining: 0us
# 0:	learn: 9.8371844	total: 105ms	remaining: 1m 45s
# 500:	learn: 1.3645066	total: 28.1s	remaining: 28s
# 999:	learn: 1.1269417	total: 54.5s	remaining: 0us
# 0:	learn: 9.8444439	total: 60.3ms	remaining: 1m
# 500:	learn: 1.3638521	total: 27.2s	remaining: 27.1s
# 999:	learn: 1.1253947	total: 52.4s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.3490753	total: 65.5ms	remaining: 1m 5s
# 500:	learn: 0.8255493	total: 26.3s	remaining: 26.2s
# 999:	learn: 0.6517739	total: 49.7s	remaining: 0us
# 0:	learn: 9.3658810	total: 62.9ms	remaining: 1m 2s
# 500:	learn: 0
	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.6300055	total: 96.3ms	remaining: 1m 36s
# 500:	learn: 1.0054697	total: 26.6s	remaining: 26.5s
# 999:	learn: 0.8043916	total: 52.2s	remaining: 0us
# 0:	learn: 9.6473875	total: 58.7ms	remaining: 58.7s
# 500:	learn: 0.9984078	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.8008593	total: 54.3s	remaining: 0us
# 0:	learn: 9.6240036	total: 58.6ms	remaining: 58.5s
# 500:	learn: 1.0054264	total: 26.8s	remaining: 26.7s
# 999:	learn: 0.8067094	total: 51.8s	remaining: 0us
# 0:	learn: 9.6345085	total: 60ms	remaining: 59.9s
# 500:	learn: 1.0110936	total: 27.3s	remaining: 27.1s
# 999:	learn: 0.8061500	total: 51.7s	remaining: 0us
# 0:	learn: 9.6415427	total: 66.1ms	remaining: 1m 5s
# 500:	learn: 1.0064837	total: 24.6s	remaining: 24.5s
# 999:	learn: 0.8055307	total: 51.1s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.2045996	total: 77ms	remaining: 1m 16s
# 500:	learn: 0.7786468	total: 28.1s	remaining: 28s
# 999:	learn: 0.6148514	total: 55.4s	remaining: 0us
# 0:	learn: 9.2211474	total: 71.6ms	remaining: 1m 11s
# 500:	learn: 0.7742203	total: 27.8s	remaining: 27.7s
# 999:	learn: 0.6108911	total: 54.6s	remaining: 0us
# 0:	learn: 9.1990405	total: 64.1ms	remaining: 1m 4s
# 500:	learn: 0.7681151	total: 27.9s	remaining: 27.8s
# 999:	learn: 0.6104794	total: 54.5s	remaining: 0us
# 0:	learn: 9.2088349	total: 73ms	remaining: 1m 12s
# 500:	learn: 0.7709207	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.6078014	total: 54.9s	remaining: 0us
# 0:	learn: 9.2158012	total: 66.5ms	remaining: 1m 6s
# 500:	learn: 0.7817146	total: 25.3s	remaining: 25.2s
# 999:	learn: 0.6147955	total: 51.8s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.3413628	total: 67.3ms	remaining: 1m 7s
# 500:	learn: 0.5353420	total: 29.5s	remaining: 29.4s
# 999:	learn: 0.3998251	total: 57.7s	remaining: 0us
# 0:	learn: 9.3580475	total: 56.9ms	remaining: 56.8s
# 500:	learn: 0.5316423	total: 30.7s	remaining: 30.6s
# 999:	learn: 0.3954177	total: 58.3s	remaining: 0us
# 0:	learn: 9.3353867	total: 66.4ms	remaining: 1m 6s
# 500:	learn: 0.5297252	total: 28.6s	remaining: 28.5s
# 999:	learn: 0.3966841	total: 56.7s	remaining: 0us
# 0:	learn: 9.3455985	total: 66.4ms	remaining: 1m 6s
# 500:	learn: 0.5322724	total: 29.3s	remaining: 29.2s
# 999:	learn: 0.3950277	total: 58.7s	remaining: 0us
# 0:	learn: 9.3525918	total: 76ms	remaining: 1m 15s
# 500:	learn: 0.5316553	total: 28.3s	remaining: 28.2s
# 999:	learn: 0.3976966	total: 55.9s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9
	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 8.9963971	total: 81.2ms	remaining: 1m 21s
# 500:	learn: 0.4709559	total: 32.3s	remaining: 32.2s
# 999:	learn: 0.3544930	total: 1m 2s	remaining: 0us
# 0:	learn: 9.0123288	total: 80.8ms	remaining: 1m 20s
# 500:	learn: 0.4678392	total: 32s	remaining: 31.9s
# 999:	learn: 0.3482957	total: 1m 2s	remaining: 0us
# 0:	learn: 8.9909911	total: 68.4ms	remaining: 1m 8s
# 500:	learn: 0.4695715	total: 32.7s	remaining: 32.5s
# 999:	learn: 0.3518646	total: 1m 4s	remaining: 0us
# 0:	learn: 9.0008512	total: 84.9ms	remaining: 1m 24s
# 500:	learn: 0.4742345	total: 32.3s	remaining: 32.2s
# 999:	learn: 0.3546151	total: 1m 3s	remaining: 0us
# 0:	learn: 9.0072927	total: 119ms	remaining: 1m 58s
# 500:	learn: 0.4717445	total: 32.4s	remaining: 32.3s
# 999:	learn: 0.3533006	total: 1m 3s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.0077269	total: 147ms	remaining: 2m 26s
# 500:	learn: 0.5365706	total: 49.9s	remaining: 49.7s
# 999:	learn: 0.4091395	total: 1m 35s	remaining: 0us
# 0:	learn: 9.0239819	total: 95.2ms	remaining: 1m 35s
# 500:	learn: 0.5338814	total: 55.5s	remaining: 55.3s
# 999:	learn: 0.4084127	total: 1m 49s	remaining: 0us
# 0:	learn: 9.0015108	total: 229ms	remaining: 3m 48s
# 500:	learn: 0.5393621	total: 55.7s	remaining: 55.4s
# 999:	learn: 0.4105530	total: 1m 47s	remaining: 0us
# 0:	learn: 9.0122732	total: 111ms	remaining: 1m 50s
# 500:	learn: 0.5372770	total: 54.5s	remaining: 54.2s
# 999:	learn: 0.4093070	total: 1m 47s	remaining: 0us
# 0:	learn: 9.0182275	total: 160ms	remaining: 2m 39s
# 500:	learn: 0.5408037	total: 53.8s	remaining: 53.6s
# 999:	learn: 0.4125140	total: 1m 47s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9.0090157	total: 53.3ms	remaining: 53.2s
# 500:	learn: 0.5855213	total: 21.1s	remaining: 21s
# 999:	learn: 0.4445641	total: 42.5s	remaining: 0us
# 0:	learn: 9.0255909	total: 46.7ms	remaining: 46.7s
# 500:	learn: 0.5749748	total: 20.6s	remaining: 20.5s
# 999:	learn: 0.4377554	total: 41.4s	remaining: 0us
# 0:	learn: 9.0034849	total: 86.5ms	remaining: 1m 26s
# 500:	learn: 0.5789688	total: 23.6s	remaining: 23.5s
# 999:	learn: 0.4409508	total: 45.2s	remaining: 0us
# 0:	learn: 9.0137954	total: 51.9ms	remaining: 51.8s
# 500:	learn: 0.5796534	total: 22.2s	remaining: 22.1s
# 999:	learn: 0.4428864	total: 43.5s	remaining: 0us
# 0:	learn: 9.0200815	total: 49.3ms	remaining: 49.3s
# 500:	learn: 0.5802322	total: 21.4s	remaining: 21.3s
# 999:	learn: 0.4389614	total: 41.9s	remaining: 0us
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 9
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 8.9968495	total: 86.9ms	remaining: 1m 26s
# 500:	learn: 0.4678020	total: 26.6s	remaining: 26.5s
# 999:	learn: 0.3497472	total: 52.3s	remaining: 0us
# 0:	learn: 9.0128425	total: 58.8ms	remaining: 58.7s
# 500:	learn: 0.4638766	total: 26.6s	remaining: 26.5s
# 999:	learn: 0.3504935	total: 51.8s	remaining: 0us
# 0:	learn: 8.9909170	total: 59.5ms	remaining: 59.5s
# 500:	learn: 0.4684425	total: 23.8s	remaining: 23.7s
# 999:	learn: 0.3495575	total: 49.1s	remaining: 0us
# 0:	learn: 9.0017704	total: 44.7ms	remaining: 44.7s
# 500:	learn: 0.4720000	total: 26.2s	remaining: 26.1s
# 999:	learn: 0.3523784	total: 52.4s	remaining: 0us
# 0:	learn: 9.0078083	total: 59.5ms	remaining: 59.5s
# ...
# 0:	learn: 8.9967931	total: 59.7ms	remaining: 59.6s
# 500:	learn: 0.4546723	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.3362891	total: 53.3s	remaining: 0us
# 0:	learn: 9.0127898	total: 44.8ms	remaining: 44.7s
# 500:	learn: 0.4565644	total: 26.2s	remaining: 26.1s
# 999:	learn: 0.3378520	total: 51.6s	remaining: 0us
# 0:	learn: 8.9908602	total: 59.3ms	remaining: 59.2s
# 500:	learn: 0.4578867	total: 25.9s	remaining: 25.8s
# 999:	learn: 0.3373519	total: 53.3s	remaining: 0us
# 0:	learn: 9.0017160	total: 59.9ms	remaining: 59.9s
# 500:	learn: 0.4632141	total: 24.5s	remaining: 24.4s
# 999:	learn: 0.3385534	total: 47.5s	remaining: 0us
# 0:	learn: 9.0077524	total: 75ms	remaining: 1m 14s
# 500:	learn: 0.4615559	total: 28s	remaining: 27.9s
# 999:	learn: 0.3390797	total: 54s	remaining: 0us
# 0:	learn: 9.0020631	total: 60.9ms	remaining: 1m
# 500:	learn: 0.4613180	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.3396596	total: 54.7s	remaining: 0us
# 0:	learn: 9.0020631	total: 64.5ms	remaining: 1m 4s
# 500:	learn: 0.4613178	total: 26.7s	remaining: 26.6s
# 999:	learn: 0.3396593	total: 54.9s	remaining: 0us
# Fold 0
# 0:	learn: 9.0087792	total: 89.2ms	remaining: 1m 29s
# 500:	learn: 0.4608927	total: 27.9s	remaining: 27.8s
# 999:	learn: 0.3387171	total: 52.1s	remaining: 0us
# 0:	learn: 8.3786298	total: 167ms	remaining: 2m 46s
# 500:	learn: 0.4498471	total: 1m 14s	remaining: 1m 13s
# 999:	learn: 0.3318016	total: 2m 24s	remaining: 0us
# 0:	learn: 9.0087784	total: 64.9ms	remaining: 1m 4s
# 500:	learn: 0.4571537	total: 26.2s	remaining: 26.1s
# 999:	learn: 0.3361945	total: 52.1s	remaining: 0us
# 0:	learn: 9.0165836	total: 60.7ms	remaining: 1m
# 500:	learn: 0.4572078	total: 24.6s	remaining: 24.5s
# 999:	learn: 0.3343958	total: 49.4s	remaining: 0us
# 0:	learn: 9.0144001	total: 58.7ms	remaining: 58.6s
# 500:	learn: 0.4598997	total: 24.7s	remaining: 24.6s
# 999:	learn: 0.3359316	total: 50s	remaining: 0us
# 0:	learn: 9.0032102	total: 63.3ms	remaining: 1m 3s
# 500:	learn: 0.4498939	total: 26.3s	remaining: 26.2s
# 999:	learn: 0
total: 27.4s	remaining: 27.3s
# 999:	learn: 0.3354294	total: 54.7s	remaining: 0us
# 0:	learn: 9.0119630	total: 63.8ms	remaining: 1m 3s
# 500:	learn: 0.4577246	total: 26.9s	remaining: 26.8s
# 999:	learn: 0.3352680	total: 51.2s	remaining: 0us
# 0:	learn: 9.0105517	total: 47.8ms	remaining: 47.7s
# 500:	learn: 0.4521528	total: 26.4s	remaining: 26.3s
# 999:	learn: 0.3317161	total: 52.9s	remaining: 0us
# 0:	learn: 9.0185349	total: 70ms	remaining: 1m 9s
# 500:	learn: 0.4554699	total: 27.6s	remaining: 27.5s
# 999:	learn: 0.3335756	total: 53.1s	remaining: 0us
# 0:	learn: 8.3936323	total: 312ms	remaining: 5m 12s
# 500:	learn: 0.4384076	total: 1m 13s	remaining: 1m 12s
# 999:	learn: 0.3214025	total: 2m 23s	remaining: 0us
# 0:	learn: 8.3836832	total: 164ms	remaining: 2m 43s
# 500:	learn: 0.4424373	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3219811	total: 2m 23s	remaining: 0us
# 0:	learn: 8.3833431	total: 165ms	remaining: 2m 45s
# 500:	learn: 0.4431807	total: 1m 13s	remaining: 1m 12s
# 999:	learn: 0.3237237	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3820479	total: 144ms	remaining: 2m 24s
# 500:	learn: 0.4405568	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3229038	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3875427	total: 162ms	remaining: 2m 42s
# 500:	learn: 0.4449170	total: 1m 15s	remaining: 1m 15s
# 999:	learn: 0.3232576	total: 2m 25s	remaining: 0us
# 0:	learn: 9.0229194	total: 63.9ms	remaining: 1m 3s
# 500:	learn: 0.4588396	total: 27s	remaining: 26.9s
# 999:	learn: 0.3350216	total: 53.1s	remaining: 0us
# 0:	learn: 9.0119404	total: 66.4ms	remaining: 1m 6s
# 500:	learn: 0.4605091	total: 27.4s	remaining: 27.3s
# 999:	learn: 0.3354294	total: 52.8s	remaining: 0us
# 0:	learn: 9.0119630	total: 65.2ms	remaining: 1m 5s
# 500:	learn: 0.4566703	total: 27.1s	remaining: 27s
# 999:	learn: 0.3359232	total: 53.3s	remaining: 0us
# 0:	learn: 9.0105517	total: 66.4ms	remaining: 1m 6s
# 500:	learn: 0.4571273	total: 27.8s	remaining: 27.7s
# 999:	learn: 0.3330522	total: 54.3s	remaining: 0us
# 0:	learn: 9.0185349	total: 60.2ms	remaining: 1m
# 500:	learn: 0.4567278	total: 26.8s	remaining: 26.7s
# 999:	learn: 0.3343449	total: 52.4s	remaining: 0us
# Learning rate set to 0.077246
# 0:	learn: 9.2201993	total: 77.6ms	remaining: 1m 17s
# 500:	learn: 0.4095129	total: 23.8s	remaining: 23.7s
# 999:	learn: 0.3884166	total: 48s	remaining: 0us
# CV RMSE: 0.1549357000802488
# Fold 2
# 0:	learn: 9.0148356	total: 61.2ms	remaining: 1m 1s
# 500:	learn: 0.4571385	total: 25.9s	remaining: 25.8s
# 999:	learn: 0.3382956	total: 52.4s	remaining: 0us
# 0:	learn: 8.3843148	total: 215ms	remaining: 3m 34s
# 500:	learn: 0.4469145	total: 1m 14s	remaining: 1m 14s
# 999:	learn: 0.3321949	total: 2m 25s	remaining: 0us
# 0:	learn: 9.0148356	total: 66.4ms	remaining: 1m 6s
# 500:	learn: 0.4571385	total: 26.4s	remaining: 26.3s
# 999:	learn: 0.3382956	total: 53.2s	remaining: 0us
# 0:	learn: 9.0095105	total: 58.7ms	remaining: 58.7s
# 500:	learn: 0.4569831	total: 28.2s	remaining: 28.1s
# 999:	learn: 0.3324141	total: 51.5s	remaining: 0us
# 0:	learn: 9.0167403	total: 61.4ms	remaining: 1m 1s
# 500:	learn: 0.4586098	total: 26.2s	remaining: 26.1s
# 999:	learn: 0.
total: 1m 12s	remaining: 1m 12s
# 999:	learn: 0.3286870	total: 2m 23s	remaining: 0us
# 0:	learn: 9.0237182	total: 57.6ms	remaining: 57.5s
# 500:	learn: 0.4620037	total: 25.4s	remaining: 25.3s
# 999:	learn: 0.3391181	total: 50.4s	remaining: 0us
# 0:	learn: 9.0309111	total: 77.7ms	remaining: 1m 17s
# 500:	learn: 0.4564082	total: 26.4s	remaining: 26.3s
# 999:	learn: 0.3335055	total: 52.4s	remaining: 0us
# 0:	learn: 9.0094038	total: 63.6ms	remaining: 1m 3s
# 500:	learn: 0.4532075	total: 27.1s	remaining: 27s
# 999:	learn: 0.3325117	total: 51.3s	remaining: 0us
# 0:	learn: 9.0201064	total: 56.6ms	remaining: 56.5s
# 500:	learn: 0.4549129	total: 25.2s	remaining: 25.1s
# 999:	learn: 0.3318735	total: 51s	remaining: 0us
# 0:	learn: 9.0231763	total: 64.6ms	remaining: 1m 4s
# 500:	learn: 0.4558811	total: 25.4s	remaining: 25.3s
# 999:	learn: 0.3348201	total: 52s	remaining: 0us
# 0:	learn: 9.0364984	total: 48ms	remaining: 47.9s
# 500:	learn: 0.4573343	total: 26.8s	remaining: 26.7s
# 999:	learn: 0.3346105	total: 52.4s	remaining: 0us
# 0:	learn: 8.3994698	total: 217ms	remaining: 3m 37s
# 500:	learn: 0.4380168	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3218693	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3799221	total: 169ms	remaining: 2m 49s
# 500:	learn: 0.4378200	total: 1m 13s	remaining: 1m 12s
# 999:	learn: 0.3211121	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3898678	total: 169ms	remaining: 2m 49s
# 500:	learn: 0.4400195	total: 1m 9s	remaining: 1m 9s
# 999:	learn: 0.3228773	total: 2m 18s	remaining: 0us
# 0:	learn: 8.3927860	total: 149ms	remaining: 2m 28s
# 500:	learn: 0.4446294	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3238694	total: 2m 25s	remaining: 0us
# 0:	learn: 8.4048735	total: 164ms	remaining: 2m 44s
# 500:	learn: 0.4416232	total: 1m 12s	remaining: 1m 12s
# 999:	learn: 0.3225615	total: 2m 23s	remaining: 0us
# 0:	learn: 9.0309111	total: 55.6ms	remaining: 55.5s
# 500:	learn: 0.4564082	total: 26.2s	remaining: 26.1s
# 999:	learn: 0.3335055	total: 53.1s	remaining: 0us
# 0:	learn: 9.0094038	total: 52.8ms	remaining: 52.7s
# 500:	learn: 0.4532075	total: 25.5s	remaining: 25.4s
# 999:	learn: 0.3325117	total: 50.4s	remaining: 0us
# 0:	learn: 9.0201064	total: 74.2ms	remaining: 1m 14s
# 500:	learn: 0.4549129	total: 28s	remaining: 27.9s
# 999:	learn: 0.3318735	total: 54s	remaining: 0us
# 0:	learn: 9.0231763	total: 65.7ms	remaining: 1m 5s
# 500:	learn: 0.4554087	total: 27.8s	remaining: 27.7s
# 999:	learn: 0.3350360	total: 53.8s	remaining: 0us
# 0:	learn: 9.0364984	total: 113ms	remaining: 1m 53s
# 500:	learn: 0.4573343	total: 28.4s	remaining: 28.3s
# 999:	learn: 0.3346105	total: 53.8s	remaining: 0us
# Learning rate set to 0.077246
# 0:	learn: 9.2294342	total: 44.5ms	remaining: 44.5s
# 500:	learn: 0.4095665	total: 23.6s	remaining: 23.5s
# 999:	learn: 0.3892270	total: 46.6s	remaining: 0us
# CV RMSE: 0.3111355193517691
# Fold 4
# 0:	learn: 8.9962813	total: 66.7ms	remaining: 1m 6s
# 500:	learn: 0.4606912	total: 27.4s	remaining: 27.3s
# 999:	learn: 0.3387174	total: 53.7s	remaining: 0us
# 0:	learn: 8.3692087	total: 187ms	remaining: 3m 6s
# 500:	learn: 0.4446069	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3282571	total: 2m 26s	remaining: 0us
# 0:	learn: 8.9962813	total: 66ms	remaining: 1m 5s
# 500:	learn: 0.4606912	total: 25.5s	remaining: 25.4s
# 999:	learn: 0.3387174	total: 51.3s	remaining: 0us
# 0:	learn: 8.9972871	total: 64.1ms	remaining: 1m 4s
# 500:	learn: 0.4569237	total: 26.6s	remaining: 26.5s
# 999:	learn: 0.3348476	total: 51.6s	remaining: 0us
# 0:	learn: 8.9892126	total: 66.9ms	remaining: 1m 6s
# 500:	learn: 0.4620850	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.3366268	total: 52.4s	remaining: 0us
# 0:	learn: 8.9906116	total: 50.2ms	remaining: 50.1s
# 500:	learn: 0.4531577	total: 24.7s	remaining: 24.6s
# 999:	learn: 0.3314593	total: 50s	remaining: 0us
# 0:	learn: 9.0047402	total: 62.9ms	remaining: 1m 2s
# 500:	learn: 0.4556842	total: 27.3s	remaining: 27.2s
# 999:	learn: 0.3335236	total: 52.8s	remaining: 0us
# 0:	learn: 9.0034597	total: 63.2ms	remaining: 1m 3s
# 500:	learn: 0.4590559	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.3366825	total: 52.7s	remaining: 0us
# 0:	learn: 8.3691176	total: 163ms	remaining: 2m 42s
# 500:	learn: 0.4431031	total: 1m 13s	remaining: 1m 13s
# 999:	learn: 0.3221134	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3617171	total: 170ms	remaining: 2m 50s
# 500:	learn: 0.4404995	total: 1m 14s	remaining: 1m 13s
# 999:	learn: 0.3208463	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3636311	total: 177ms	remaining: 2m 56s
# 500:	learn: 0.4429166	total: 1m 13s	remaining: 1m 12s
# 999:	learn: 0.3221799	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3756731	total: 163ms	remaining: 2m 43s
# 500:	learn: 0.4414914	total: 1m 14s	remaining: 1m 13s
# 999:	learn: 0.3212935	total: 2m 24s	remaining: 0us
# 0:	learn: 8.3749406	total: 155ms	remaining: 2m 34s
# 500:	learn: 0.4433253	total: 1m 12s	remaining: 1m 11s
# 999:	learn: 0.3239251	total: 2m 23s	remaining: 0us
# 0:	learn: 8.9972871	total: 83.1ms	remaining: 1m 22s
# 500:	learn: 0.4569237	total: 27.3s	remaining: 27.2s
# 999:	learn: 0.3348476	total: 53.2s	remaining: 0us
# 0:	learn: 8.9892126	total: 62.9ms	remaining: 1m 2s
# 500:	learn: 0.4620850	total: 27.6s	remaining: 27.5s
# 999:	learn: 0.3366268	total: 54.1s	remaining: 0us
# 0:	learn: 8.9906116	total: 72.3ms	remaining: 1m 12s
# 500:	learn: 0.4531577	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.3314593	total: 53.3s	remaining: 0us
# 0:	learn: 9.0047402	total: 62.5ms	remaining: 1m 2s
# 500:	learn: 0.4556842	total: 26.1s	remaining: 25.9s
# 999:	learn: 0.3335236	total: 51.4s	remaining: 0us
# 0:	learn: 9.0034597	total: 58.2ms	remaining: 58.1s
# 500:	learn: 0.4531146	total: 26.3s	remaining: 26.2s
# 999:	learn: 0.3334734	total: 51.8s	remaining: 0us
# Learning rate set to 0.077246
# 0:	learn: 9.2017759	total: 31.1ms	remaining: 31.1s
# 500:	learn: 0.4086538	total: 31.1s	remaining: 31s
# 999:	learn: 0.3883476	total: 54.2s	remaining: 0us
# CV RMSE: 0.38865029851507993

# %% [markdown]
# ## Preprocessing

# %%
"""
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot

from joblib import Parallel, delayed
import numpy as np

model = CatBoostRegressor(verbose=1000,task_type='GPU', devices='0:1')

k_range = range(5, len(features)+1)
param_grid = dict(n_features_to_select=k_range)
grid = GridSearchCV(RFE(model), param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid.fit(train_df[features], train_df[ycol])

mask = grid.best_estimator_.support_
df = train_df[feature_names]
feature_names = df.columns[:][mask]
k = grid.best_params_['n_features_to_select']

X_new = train_df[feature_names]

def parallel_cv_scores(model, X, y, cv):
    return np.average(Parallel(n_jobs=-1)(delayed(cross_val_score)(model, X, y, cv=cv_fold, scoring='neg_mean_squared_error') for cv_fold in cv))

cv = 5
scores = parallel_cv_scores(model, X_new, train_df[ycol], cv)

print("Best number of features:", k)
print("Selected features:", feature_names)
print("Cross-validation mean squared error: %0.2f" % (-scores))
"""
# Out:
# '\nfrom sklearn.datasets import make_regression\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.feature_selection import SelectKBest\nfrom sklearn.feature_selection import mutual_info_regression\nfrom sklearn.feature_selection import RFE\nfrom sklearn.model_selection import GridSearchCV\nfrom sklearn.model_selection import cross_val_score\nfrom matplotlib import pyplot\n\nfrom joblib import Parallel, delayed\nimport numpy as np\n\nmodel = CatBoostRegressor(verbose=1000,task_type=\'GPU\', devices=\'0:1\')\n\nk_range = range(5, len(features)+1)\nparam_grid = dict(n_features_to_select=k_range)\ngrid = GridSearchCV(RFE(model), param_grid, cv=5, scoring=\'neg_mean_squared_error\', n_jobs=-1)\ngrid.fit(train_df[features], train_df[ycol])\n\nmask = grid.best_estimator_.support_\ndf = train_df[feature_names]\nfeature_names = df.columns[:][mask]\nk = grid.best_params_[\'n_features_to_select\']\n\nX_new = train_df[feature_names]\n\ndef parallel_cv_scores(model, X, y, cv):\n    return np.average(Parallel(n_jobs=-1)(delayed(cross_val_score)(model, X, y, cv=cv_fold, scoring=\'neg_mean_squared_error\') for cv_fold in cv))\n\ncv = 5\nscores = parallel_cv_scores(model, X_new, train_df[ycol], cv)\n\nprint("Best number of features:", k)\nprint("Selected features:", feature_names)\nprint("Cross-validation mean squared error: %0.2f" % (-scores))\n'

# %%
#train_df=train_df[features]
#test_df=test_df[features]

# %%
submission
# Out:
#        contest-tmp2m-14d__tmp2m   index
# 0                     28.978540  375734
# 1                     28.879029  375735
# 2                     29.080993  375736
# 3                     29.630383  375737
# 4                     29.631249  375738
# ...                         ...     ...
# 31349                  3.498991  407083
# 31350                  2.895121  407084
# 31351                  2.455746  407085
# 31352                  2.230769  407086
# 31353                  2.352499  407087
#
# [31354 rows x 2 columns]
